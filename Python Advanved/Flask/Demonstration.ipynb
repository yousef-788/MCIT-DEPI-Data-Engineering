# %%
import sqlite3

# %%
# !pip install pyodbc

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'ODBC Driver 17 for SQL Server', 'ODBC Driver 18 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
import pyodbc

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 18 for SQL Server};'
    'SERVER=localhost\\SQLEXPRESS;'
    'DATABASE=Company_SD;'
    'Trusted_Connection=yes;'
    'TrustServerCertificate=yes;'
)
cursor = conn.cursor()            
cursor.execute("select SSN, Fname +' '+Lname , Salary, Dname from Employee as Emp inner join Departments as dep on Emp.Dno = dep.Dnum")
data = cursor.fetchall()              
cursor.close()                    
conn.close()

# %%
data
# Out:
# [(223344, 'Kamel Mohamed', 1800, 'DP1'),
#  (512463, 'Edward Hanna', 1500, 'DP3'),
#  (521634, 'Maged Raoof', 1000, 'DP3'),
#  (669955, 'Mariam Adel', 750, 'DP2'),
#  (968574, 'Noha Mohamed', 1600, 'DP2')]

# %%
conn = pyodbc.connect('DRIVER={ODBC Driver 18 for SQL Server};'          
                         'SERVER=depi-sql123.database.windows.net;'
                         'DATABASE=free-sql-db-0398633;'
                        'UID=admin1;'
                        'PWD=Depi123#;')
 
 
cursor = conn.cursor()            
cursor.execute("""
select * from departments
""")
data = cursor.fetchall()
data
# Out:
# [('DP1', 10, 223344, None),
#  ('DP2', 20, 968574, datetime.datetime(2006, 1, 3, 0, 0)),
#  ('DP3', 30, 512463, datetime.datetime(2006, 1, 6, 0, 0))]

# %%
# !pip install pymongo

# %%
import pymongo

print(pymongo.__version__)
# Out:
# 4.16.0

# %%
from pymongo import MongoClient
 
conn = MongoClient('mongodb://localhost:27017')
 
db = conn['test']
data = db.Employees.find()
for i in data:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[27], line 7
#       5 db = conn['test']
#       6 data = db.Employees.find()
# ----> 7 for i in data:
#       8     print(i)
#
# File c:\Users\m\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File c:\Users\m\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File c:\Users\m\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
# ...

# %%
# !pip install flask

# %%
from flask import Flask
