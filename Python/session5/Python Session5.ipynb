# %%
# sorted  , lambda
# Working with files (Text File, Json)
# Task 1 (dicionary, while, lambda, wroking with files txt, josn)

# %%
names = ["Ahmed", "Shahd", {"Name" : "Khaled"}, "Ahmed", "Mina"]

# %%
names[2]["Name"]
# Out:
# 'Khaled'

# %%
students = {
    "St1" : {
        "Name" : "Ahmed",
        "Age" : 21
    },
    "St2" : {
        "Name" : "Shahd",
        "Age" : 16
    },
    "St3" : {
        "Name" : "Khaled",
        "Age" : 20
    },
    "St4" : {
        "Name" : "Ahmed",
        "Age" : 17
    },
    "St5" : ["Khaled", 17]
}

# %%
students["St5"][1]
# Out:
# 17

# %%
numbers =[1,5,9,3,2,8]

# %%
numbers.sort?
# Out:
# Signature: numbers.sort(*, key=None, reverse=False)
# Docstring:
# Sort the list in ascending order and return None.
#
# The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
# order of two equal elements is maintained).
#
# If a key function is given, apply it once to each list item and sort them,
# ascending or descending, according to their function values.
#
# The reverse flag can be set to sort in descending order.
# Type:      builtin_function_or_method

# %%
numbers =[1,5,9,3,2,8]


print(numbers)

numbers.sort()

print(numbers)
# Out:
# [1, 5, 9, 3, 2, 8]
# [1, 2, 3, 5, 8, 9]

# %%
names = ["Shahd" , "Ayman" , "Basmala", "Eman"]

print(names)

names.sort()

print(names)
# Out:
# ['Shahd', 'Ayman', 'Basmala', 'Eman']
# ['Ayman', 'Basmala', 'Eman', 'Shahd']

# %%
def concat(first_name, last_name):
    return first_name + " " + last_name

# %%
def get_item(item):
    return item[1]

# %%
get_item(("Shahd", 28))
# Out:
# 28

# %%
names = [("Shahd", 28) , ("Ayman", 18) , ("Basmala", 22) , ("Eman",19)]

print(names)

names.sort( key = lambda  item :  item[1],   reverse= False)

print(names)
# Out:
# [('Shahd', 28), ('Ayman', 18), ('Basmala', 22), ('Eman', 19)]
# [('Ayman', 18), ('Eman', 19), ('Basmala', 22), ('Shahd', 28)]

# %%
("Shahd", 28), ,   28
("Basmala", 22),   22
("Eman",19) ,      19
("Ayman", 18),     18

# %%
("Shahd", 28),
("Basmala", 22), 
("Eman",19) ,      
("Ayman", 18)

# %%
names.sort?
# Out:
# Signature: names.sort(*, key=None, reverse=False)
# Docstring:
# Sort the list in ascending order and return None.
#
# The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
# order of two equal elements is maintained).
#
# If a key function is given, apply it once to each list item and sort them,
# ascending or descending, according to their function values.
#
# The reverse flag can be set to sort in descending order.
# Type:      builtin_function_or_method

# %%
product = {
    "Product3" : {"Name": "Mobile" , "Price" : 300,  "Quantity" : 15},   
    "Product1" : {"Name": "PC" , "Price" : 310 , "Quantity" : 10},
    "Product2" : {"Name": "Laptop" , "Price" : 700 ,  "Quantity" : 7},
    "Product4" : {"Name": "Tablet" , "Price" : 250 ,  "Quantity" : 3},
    "Product5" : {"Name": "Printer" , "Price" : 850 ,  "Quantity" : 12},
}

# %%
dir(product)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
sorted?
# Out:
# Signature: sorted(iterable, /, *, key=None, reverse=False)
# Docstring:
# Return a new list containing all items from the iterable in ascending order.
#
# A custom key function can be supplied to customize the sort order, and the
# reverse flag can be set to request the result in descending order.
# Type:      builtin_function_or_method

# %%
sorted_products = sorted(product.items() , key = lambda item : item[1]["Price"] , reverse= True )

sorted_products
# Out:
# [('Product5', {'Name': 'Printer', 'Price': 850, 'Quantity': 12}),
#  ('Product2', {'Name': 'Laptop', 'Price': 700, 'Quantity': 7}),
#  ('Product1', {'Name': 'PC', 'Price': 310, 'Quantity': 10}),
#  ('Product3', {'Name': 'Mobile', 'Price': 300, 'Quantity': 15}),
#  ('Product4', {'Name': 'Tablet', 'Price': 250, 'Quantity': 3})]

# %%
product.items()
# Out:
# dict_items([('Product3', {'Name': 'Mobile', 'Price': 300, 'Quantity': 15}), ('Product1', {'Name': 'PC', 'Price': 310, 'Quantity': 10}), ('Product2', {'Name': 'Laptop', 'Price': 700, 'Quantity': 7}), ('Product4', {'Name': 'Tablet', 'Price': 250, 'Quantity': 3}), ('Product5', {'Name': 'Printer', 'Price': 850, 'Quantity': 12})])

# %%
students = {
    "Student3" : ["Khaled", 20],
    "Student1" : ["Ahmed", 21],
    "Student2" : ["Shahd", 16],
    "Student4" : ["Ahmed", 16],
    "Student5" : ["Khaled", 17]
}

# %%
students = {
    "Student3" : { "Name" : "Khaled", "Age" : 20},
    "Student1" : { "Name" : "Ahmed", "Age" : 21},
    "Student2" : { "Name" : "Shahd", "Age" : 16},
    "Student4" : { "Name" : "Ahmed", "Age" : 16},
    "Student5" : { "Name" : "Khaled", "Age" : 17}

}

# %%
students["Student3"]["Age"]
# Out:
# 20

# %%
sorted(students.items() , key = lambda item : item[1]["Age"])
# Out:
# [('Student2', {'Name': 'Shahd', 'Age': 16}),
#  ('Student4', {'Name': 'Ahmed', 'Age': 16}),
#  ('Student5', {'Name': 'Khaled', 'Age': 17}),
#  ('Student3', {'Name': 'Khaled', 'Age': 20}),
#  ('Student1', {'Name': 'Ahmed', 'Age': 21})]

# %%
x = ("Student3" , ["Khaled", 20])

x[1][1]
# Out:
# 20

# %%
# Working with File

# %%
message = "Welcome to Python" # memory

# %%
# files : txt , json
# Databases : SQL , NoSQL

# %%
# Files

# %%
open?
# Out:
# Signature:
# open(
#     file,
#     mode='r',
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
#     closefd=True,
#     opener=None,
# )
# Docstring:
# Open file and return a stream.  Raise OSError upon failure.
#
# file is either a text or byte string giving the name (and the path
# if the file isn't in the current working directory) of the file to
# be opened or an integer file descriptor of the file to be
# wrapped. (If a file descriptor is given, it is closed when the
# returned I/O object is closed, unless closefd is set to False.)
#
# mode is an optional string that specifies the mode in which the file
# is opened. It defaults to 'r' which means open for reading in text
# mode.  Other common values are 'w' for writing (truncating the file if
# it already exists), 'x' for creating and writing to a new file, and
# 'a' for appending (which on some Unix systems, means that all writes
# ...

# %%
object = open("country.txt")

data = object.read()

print(data)
# Out:
# Egypt officially the Arab Republic of Egypt, is a country spanning the northeast corner of Africa and southwest corner of Asia via the Sinai Peninsula.
# It is bordered by the Mediterranean Sea to the north, Palestine to the northeast, the Red Sea to the east, Sudan to the south, and Libya to the west.
# The Gulf of Aqaba in the northeast separates Egypt from Jordan and Saudi Arabia.
# Cairo is the capital, largest city, and leading cultural center, while Alexandria is the second-largest city and an important hub of industry and tourism.
# With over 107 million inhabitants, Egypt is the third-most populous country in Africa and 15th-most populated in the world

# %%
object = open("country.txt")

data = object.readlines()

print(data)
# Out:
# ['Egypt officially the Arab Republic of Egypt, is a country spanning the northeast corner of Africa and southwest corner of Asia via the Sinai Peninsula. \n', 'It is bordered by the Mediterranean Sea to the north, Palestine to the northeast, the Red Sea to the east, Sudan to the south, and Libya to the west. \n', 'The Gulf of Aqaba in the northeast separates Egypt from Jordan and Saudi Arabia. \n', 'Cairo is the capital, largest city, and leading cultural center, while Alexandria is the second-largest city and an important hub of industry and tourism. \n', 'With over 107 million inhabitants, Egypt is the third-most populous country in Africa and 15th-most populated in the world']

# %%
len(data)
# Out:
# 5

# %%
for  i in data:
    print(i.strip().split(" "))
    print("-"*20)
# Out:
# ['Egypt', 'officially', 'the', 'Arab', 'Republic', 'of', 'Egypt,', 'is', 'a', 'country', 'spanning', 'the', 'northeast', 'corner', 'of', 'Africa', 'and', 'southwest', 'corner', 'of', 'Asia', 'via', 'the', 'Sinai', 'Peninsula.']
# --------------------
# ['It', 'is', 'bordered', 'by', 'the', 'Mediterranean', 'Sea', 'to', 'the', 'north,', 'Palestine', 'to', 'the', 'northeast,', 'the', 'Red', 'Sea', 'to', 'the', 'east,', 'Sudan', 'to', 'the', 'south,', 'and', 'Libya', 'to', 'the', 'west.']
# --------------------
# ['The', 'Gulf', 'of', 'Aqaba', 'in', 'the', 'northeast', 'separates', 'Egypt', 'from', 'Jordan', 'and', 'Saudi', 'Arabia.']
# --------------------
# ['Cairo', 'is', 'the', 'capital,', 'largest', 'city,', 'and', 'leading', 'cultural', 'center,', 'while', 'Alexandria', 'is', 'the', 'second-largest', 'city', 'and', 'an', 'important', 'hub', 'of', 'industry', 'and', 'tourism.']
# --------------------
# ...

# %%
object = open("country.txt" , "w" )  # "r" -> read , "w" -> write , "a" -> append
 
object.write("welcome to Depi")

object.close()

# %%
object = open("country.txt" , "a" )  # "r" -> read , "w" -> write , "a" -> append
 
object.write("\nwelcome to Alex")

object.close()

# %%
message = input("Enter a message : ")

object = open("country.txt" , "a" )  # "r" -> read , "w" -> write , "a" -> append
 
object.write(message)

object.close()

# %%
names = ["Ahmed", "Youssef" , "Aya"]

# %%
object = open("country.txt" , "a" )  # "r" -> read , "w" -> write , "a" -> append
 
object.writelines(names)

object.close()

# %%
object =  open("session.txt" , "a" )
object.write("Weclome from the Session 5 Pyhton")
object.close()

# %%
object = open("session.txt" , "r")
data = object.read()
print(data)
object.close()
# Out:
# Weclome from the Session 5 Pyhton

# %%
with open("session.txt" , "r") as object:
    data = object.read()
    print(data)
# Out:
# Weclome from the Session 5 Pyhton

# %%
import json
with open("employees.json" , "r") as object:
    data = json.load(object)

# %%
students = {
    "Student3" : { "Name" : "Khaled", "Age" : 20},
    "Student1" : { "Name" : "Ahmed", "Age" : 21},
    "Student2" : { "Name" : "Shahd", "Age" : 16},
    "Student4" : { "Name" : "Ahmed", "Age" : 16},
    "Student5" : { "Name" : "Khaled", "Age" : 17}
}

# %%
import json
with open("students.json" , "w") as object:
   json.dump(students, object , indent=4)

# %%
data[0]["employee"]["department"]["manager"]["name"]
# Out:
# 'Rebecca Andrews'
